# %%
# !git clone https://github.com/Bonidia/BioAutoML.git BioAutoML
# Out:
# Cloning into 'BioAutoML'...
# remote: Enumerating objects: 1081, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 1081 (delta 195), reused 256 (delta 148), pack-reused 724 (from 1)
# Receiving objects: 100% (1081/1081), 82.17 MiB | 24.45 MiB/s, done.
# Resolving deltas: 100% (470/470), done.
# Updating files: 100% (416/416), done.

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 11 root root 4096 Nov  4 19:46 BioAutoML
# drwxr-xr-x  1 root root 4096 Nov  3 14:39 sample_data

# %%
# %cd /content/BioAutoML
# Out:
# /content/BioAutoML

# %%
# !ls -l
# Out:
# total 224
# -rw-r--r-- 1 root root 29761 Nov  4 19:46  BioAutoML-binary.py
# -rw-r--r-- 1 root root  3316 Nov  4 19:46  BioAutoML-env.yml
# -rw-r--r-- 1 root root 15699 Nov  4 19:46  BioAutoML-feature-manual.py
# -rw-r--r-- 1 root root 18626 Nov  4 19:46  BioAutoML-feature-mapping.py
# -rw-r--r-- 1 root root 18406 Nov  4 19:46  BioAutoML-feature-protein.py
# -rw-r--r-- 1 root root 15907 Nov  4 19:46  BioAutoML-feature.py
# -rw-r--r-- 1 root root 15716 Nov  4 19:46  BioAutoML-feature-random.py
# -rw-r--r-- 1 root root 21526 Nov  4 19:46  BioAutoML+iFeature-protein.py
# -rw-r--r-- 1 root root 25354 Nov  4 19:46  BioAutoML-multiclass.py
# drwxr-xr-x 8 root root  4096 Nov  4 19:46 'Case Studies'
# drwxr-xr-x 7 root root  4096 Nov  4 19:46  example_csv
# drwxr-xr-x 4 root root  4096 Nov  4 19:46  example_results
# drwxr-xr-x 4 root root  4096 Nov  4 19:46  exemplo_fasta
# drwxr-xr-x 2 root root  4096 Nov  4 19:46  img
# -rw-r--r-- 1 root root  1510 Nov  4 19:46  LICENSE
# drwxr-xr-x 2 root root  4096 Nov  4 19:46  MathFeature
# drwxr-xr-x 2 root root  4096 Nov  4 19:46  MathFeature-WebServer
# drwxr-xr-x 4 root root  4096 Nov  4 19:46  other-methods
# -rw-r--r-- 1 root root  8985 Nov  4 19:46  README.md

# %%
# !git submodule init
# Out:
# Submodule 'MathFeature' (https://github.com/Bonidia/MathFeature.git) registered for path 'MathFeature'
# Submodule 'MathFeature-WebServer' (https://github.com/Bonidia/MathFeature-WebServer.git) registered for path 'MathFeature-WebServer'

# %%
# !git submodule update
# Out:
# Cloning into '/content/BioAutoML/MathFeature'...
# Cloning into '/content/BioAutoML/MathFeature-WebServer'...
# Submodule path 'MathFeature': checked out '65841db23a2e2caa7fc1950e464356a4215fb297'
# Submodule path 'MathFeature-WebServer': checked out '5d13e073b30d0f9b333adb411bc843722c09d0ba'

# %%
# !sudo apt-get install python3.10 python3.10-dev python3.10-distutils -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.11).
# python3.10 set to manually installed.
# python3.10-dev is already the newest version (3.10.12-1~22.04.11).
# python3.10-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --set python3 /usr/bin/python3.10
# Out:
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
req = """biopython==1.83
numpy==1.26.4
pandas==2.2.2
scipy==1.11.4
imbalanced-learn==0.11.0
joblib==1.3.2
threadpoolctl==3.2.0
tqdm==4.66.5
requests==2.31.0
urllib3==2.0.7
cryptography==41.0.7
cffi==1.16.0
pymongo==4.6.1
python-dateutil==2.8.2
pytz==2024.1
six==1.16.0
deap==1.4.1
hyperopt==0.2.7
lightgbm==4.1.0
xgboost==2.0.3
catboost==1.2.5
igraph==0.11.5
texttable==1.7.0
cloudpickle==2.2.1
"""

with open("requirements.txt", "w") as f:
    f.write(req)

print("✅ requirements.txt criado!")
# Out:
# ✅ requirements.txt criado!

# %%
# !pip install -r requirements.txt

# %%
# !pip install scikit-learn==1.3.2 tpot --force-reinstall --no-cache-dir

# %%
# !pip install matplotlib==3.8.4

# %%
# !apt-get -y install python3-igraph

# %%
# !python BioAutoML-feature.py -fasta_train Case\ Studies/CS-I-A/E_coli/train/rRNA.fasta Case\ Studies/CS-I-A/E_coli/train/sRNA.fasta -fasta_label_train rRNA sRNA -fasta_test Case\ Studies/CS-I-A/E_coli/test/rRNA.fasta Case\ Studies/CS-I-A/E_coli/test/sRNA.fasta -fasta_label_test rRNA sRNA -output test_directory

# %%
# %cd /content/BioAutoML/test_directory
# Out:
# /content/BioAutoML/test_directory

# %%
# !ls -l
# Out:
# total 200
# drwxr-xr-x 2 root root   4096 Nov  4 19:52  best_descriptors
# -rw-r--r-- 1 root root   4122 Nov  4 19:54  best_feature_test.csv
# -rw-r--r-- 1 root root  16491 Nov  4 19:54  best_feature_train.csv
# drwxr-xr-x 4 root root   4096 Nov  4 19:50  feat_extraction
# -rw-r--r-- 1 root root    155 Nov  4 19:54  feature_importance.csv
# -rw-r--r-- 1 root root    114 Nov  4 19:54  metrics_test.csv
# -rw-r--r-- 1 root root     55 Nov  4 19:54  test_confusion_matrix.csv
# -rw-r--r-- 1 root root   1214 Nov  4 19:54  test_predictions.csv
# -rw-r--r-- 1 root root 139913 Nov  4 19:54  trained_model.sav
# -rw-r--r-- 1 root root     62 Nov  4 19:54  training_confusion_matrix.csv
# -rw-r--r-- 1 root root    168 Nov  4 19:54 'training_kfold(10)_metrics.csv'

# %%
# !cat test_confusion_matrix.csv
# Out:
# REAL,rRNA,sRNA,All
# rRNA,8,0,8
# sRNA,0,33,33
# All,8,33,41
